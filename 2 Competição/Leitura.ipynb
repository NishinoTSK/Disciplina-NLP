# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
xtrain = pd.read_csv("/content/drive/MyDrive/NLP/2_Competição/Dataset/train.conll", sep = ' ', skip_blank_lines=True)

# %%
len(xtrain)
# Out:
# 306833

# %%
xtest = pd.read_csv("/content/drive/MyDrive/NLP/2_Competição/Dataset/test.conll", sep = ' ', skip_blank_lines=True)

# %%
len(xtest)
# Out:
# 11238

# %%
from sklearn.model_selection import train_test_split

train, dev = train_test_split(xtrain, test_size=0.210014 , shuffle=False)

# %%
len(xtest)
# Out:
# 11238

# %%
len(dev)
# Out:
# 64440

# %%
xtest.head(50)
# Out:
#               AÇÃO
# 0        MONITÓRIA
# 1                .
# 2       PRESCRIÇÃO
# 3               DA
# 4        PRETENSÃO
# 5        MONITÓRIA
# 6                .
# 7   RECONHECIMENTO
# 8                .
# 9       MANUTENÇÃO
# 10              DA
# 11        SENTENÇA
# 12               .
# 13               2
# 14               .
# 15               3
# 16               .
# 17        Brasilia
# 18               (
# 19              DF
# 20               )
# 21               ,
# 22              15
# 23              de
# 24           Março
# 25              de
# 26            2018
# 27               .
# 28               É
# 29               o
# 30       relatório
# 31               .
# 32           CIVIL
# 33               E
# 34      PROCESSUAL
# 35           CIVIL
# 36               .
# 37        APELAÇÃO
# 38           CÍVEL
# 39               .
# 40        EXECUÇÃO
# 41   EXTRAJUDICIAL
# 42               .
# 43          CÉDULA
# 44              DE
# 45         CRÉDITO
# ...

# %%
dev.head(5)
# Out:
#                     E  O
# 248359         Quanto  O
# 248360             às  O
# 248361  apresentações  O
# 248362              ,  O
# 248363            não  O

# %%
train.to_csv('/content/drive/MyDrive/NLP/2_Competição/Dataset/trainC.conll',sep=' ',index=False)

# %%
dev.to_csv('/content/drive/MyDrive/NLP/2_Competição/Dataset/testC.conll',sep=' ',index=False)
