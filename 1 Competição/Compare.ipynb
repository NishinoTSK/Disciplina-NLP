# %%
import pandas as pd
import numpy as np

path = '/content/drive/MyDrive/NLP/DataSet da Primeira Competição/'

base = pd.read_csv(path + 'finalSGD20.csv')
# base = pd.read_csv(path + 'finalSGD14.csv')
compare = pd.read_csv(path+ 'finalSGD19.csv')

base = base.Category
compare = compare.Category

err = 0
for x in range(1,1640):
  if base[x] != compare[x]:
    err = err + 1

err
# Out:
# 21

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
